# %%
import pandas as pd
df = pd.read_csv('./iip_vietnam_data/iip_vietnam.csv')
df
# Out:
#   Country Name Country Code                                Indicator Name  \
# 0      Vietnam          VNM  Manufacturing, value added (annual % growth)
#
#       Indicator Code  1960  1961  1962  1963  1964  1965  ...      2014  \
# 0  NV.IND.MANF.KD.ZG   NaN   NaN   NaN   NaN   NaN   NaN  ...  6.498369
#
#        2015       2016       2017       2018      2019     2020      2021  \
# 0  9.185779  11.140218  12.126038  11.480373  9.594826  4.99214  6.053331
#
#    2022  Unnamed: 67
# 0   NaN          NaN
#
# [1 rows x 68 columns]

# %%
df_new = df.iloc[:, 44:66]
df_transposed = df_new.T
df_transposed.rename_axis('Year', inplace=True)
df_transposed
# df_transposed.columns = ["source", "count"]
# Out:
#               0
# Year
# 2000  11.684191
# 2001  11.347132
# 2002  11.596028
# 2003  11.534100
# 2004  10.864302
# 2005  12.919688
# 2006  13.355367
# 2007  12.374568
# 2008   9.783720
# 2009   2.762156
# 2010 -21.838759
# 2011  12.591333
# 2012   8.381804
# 2013   6.500156
# 2014   6.498369
# 2015   9.185779
# 2016  11.140218
# 2017  12.126038
# 2018  11.480373
# 2019   9.594826
# 2020   4.992140
# 2021   6.053331

# %%
init_iip = 15.25
for index, row in df_transposed.iterrows():
    init_iip = (100 + row[0])/100 * init_iip
    print('year', index, '| change (%):', row[0],'|value: ', init_iip)
# Out:
# year 2000 | change (%): 11.6841906176592 |value:  17.031839069193026
# year 2001 | change (%): 11.3471318251261 |value:  18.96446430061769
# year 2002 | change (%): 11.5960279422362 |value:  21.163588880012725
# year 2003 | change (%): 11.5340998405604 |value:  23.60461835127913
# year 2004 | change (%): 10.8643019293398 |value:  26.169095358230443
# year 2005 | change (%): 12.9196878135597 |value:  29.55006078214656
# year 2006 | change (%): 13.3553671157861 |value:  33.49657988254016
# year 2007 | change (%): 12.3745677041766 |value:  37.64163683868869
# year 2008 | change (%): 9.78372031362444 |value:  41.32438930845622
# year 2009 | change (%): 2.76215613211888 |value:  42.46583346180042
# year 2010 | change (%): -21.8387588657443 |value:  33.19182249174927
# year 2011 | change (%): 12.5913333432903 |value:  37.371115504398624
# year 2012 | change (%): 8.38180401719153 |value:  40.503489165015594
# year 2013 | change (%): 6.50015603017199 |value:  43.136279158405415
# ...

# %%
# Create a sample DataFrame
data = {'2000': [10, 20, 30],
        '2001': [15, 25, 35],
        '2002': [18, 28, 38]}
df = pd.DataFrame(data, index=['A', 'B', 'C'])

# Transpose the DataFrame
df_transposed = df.transpose()

# Set the name of the index to 'Year'
df_transposed.rename_axis('Year', inplace=True)

print(df_transposed)
# Out:
#        A   B   C
# Year
# 2000  10  20  30
# 2001  15  25  35
# 2002  18  28  38
